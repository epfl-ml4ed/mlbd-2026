# %% [markdown]
# # M4 | Research Investigation Notebook
#
# In this notebook, you will do a research investigation of your chosen dataset in teams. You can begin by formally selecting your research question, then processing your data, creating a predictive model, and evaluating your model's results. This is a template notebook, and you are free to choose your own structure and reorganize code.
#
# For grading, please make sure your notebook has all cells already run. You will also need to write a short, 2 page report about your design decisions as a team, to be uploaded to Moodle in the form of a PDF file next to this Jupyter notebook.

# %%
# Import the tables of the data set as dataframes.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = './data' # You many change the directory

# Your code goes here

# %% [markdown]
# ## Research Question

# %% [markdown]
# **Research question:**
# *Your chosen research question goes here*

# %% [markdown]
# ## Data Preprocessing
#
# In this section, you are asked to preprocess your data in a way that is relevant for the model.

# %%
# Your code for data processing goes here

# %% [markdown]
# ## Model Building
#
# Train a model for your research question.

# %%
# Your code for training a model goes here

# %% [markdown]
# ## Model Evaluation
# Use appropriate metrics to evaluate your model.

# %%
# Your code for model evaluation goes here
